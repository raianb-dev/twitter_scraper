# %%
import requests, json, response
import pandas as pd

# %%
head = {
            'x-guest-token':'1559321644501434371',
            'authorization':'Bearer AAAAAAAAAAAAAAAAAAAAANRILgAAAAAAnNwIzUejRCOuH5E6I8xnZz4puTs%3D1Zv7ttfk8LF81IUq16cHjhLTvJu4FA33AGWWjCpTnA'
}

baseUrl = 'https://twitter.com/i/api/1.1/users/recommendations.json?limit=100'# <-- Limit of users scraper


req = requests.get(baseUrl, headers=head)
req = req.text
data = pd.read_json(req)
df = pd.DataFrame(data)
df = df['user']
df = pd.DataFrame(list(df))
df = df[[
            'id',
            'name',
            'screen_name',
            'description',
            'followers_count',
            'friends_count',
            'created_at',
            'location',
            'favourites_count',
            'statuses_count',
            'url'
            
        ]]
df.head(50)
# Out:
#                      id                 name      screen_name  \
# 0             231579149        netflixbrasil    NetflixBrasil
# 1             230186518          Whindersson      whindersson
# 2            2203709322                   +a            maisa
# 3             141817380               Anitta           Anitta
# 4             158487331            Neymar Jr         neymarjr
# 5               8802752                   g1               g1
# 6            2921763658     marília mendonça     MariliaMReal
# 7              14128609        Felipe Neto 🦉       felipeneto
# 8             228023472                 caze         Casimiro
# 9              39342378     padrefabiodemelo    pefabiodemelo
# 10            432983617               luscas           luscas
# 11            128372940    Jair M. Bolsonaro    jairbolsonaro
# 12             58603510     Bruna Marquezine    BruMarquezine
# 13           2670726740                 Lula      LulaOficial
# ...

# %%
url = 'https://twitter.com/i/api/graphql/X0G3yrqmH2bBryO4kPAVMQ/UserTweets?variables=%7B%22userId%22%3A%22230186518%22%2C%22count%22%3A40%2C%22includePromotedContent%22%3Atrue%2C%22withQuickPromoteEligibilityTweetFields%22%3Atrue%2C%22withSuperFollowsUserFields%22%3Atrue%2C%22withDownvotePerspective%22%3Afalse%2C%22withReactionsMetadata%22%3Afalse%2C%22withReactionsPerspective%22%3Afalse%2C%22withSuperFollowsTweetFields%22%3Atrue%2C%22withVoice%22%3Atrue%2C%22withV2Timeline%22%3Atrue%7D&features=%7B%22dont_mention_me_view_api_enabled%22%3Atrue%2C%22interactive_text_enabled%22%3Atrue%2C%22responsive_web_uc_gql_enabled%22%3Atrue%2C%22vibe_api_enabled%22%3Atrue%2C%22responsive_web_edit_tweet_api_enabled%22%3Atrue%2C%22standardized_nudges_misinfo%22%3Atrue%2C%22tweet_with_visibility_results_prefer_gql_limited_actions_policy_enabled%22%3Afalse%2C%22responsive_web_enhance_cards_enabled%22%3Afalse%7D'
req = requests.get(url, headers=head)
req = req.text
data = json.loads(req)
print(data)
data = data['data']
data = data['user']
data = data['result']
data = data['timeline_v2']
data = data['timeline']
data = data['instructions'][1]

quote_count = df.loc[14]
reply_count = df.loc[15]
retweet_count = df.loc[16]
# Out:
# {'errors': [{'message': 'Bad guest token', 'code': 239}]}
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/x4/4rwvtnrs5vz_qqqv17_nrswr0000gn/T/ipykernel_4873/342243007.py in <module>
#       4 data = json.loads(req)
#       5 print(data)
# ----> 6 data = data['data']
#       7 data = data['user']
#       8 data = data['result']
#
# KeyError: 'data'

# %%
quote = []
for i in range(10) :
    data = data['entries'][i]
    data = data['content']
    data = data['itemContent']
    data = data['tweet_results']
    data = data['result']
    df = pd.DataFrame(data)
    df = df.rename_axis('index').reset_index()
    df = df['legacy']
    quote.append(df.loc[14])
quote
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/x4/4rwvtnrs5vz_qqqv17_nrswr0000gn/T/ipykernel_4873/358490049.py in <module>
#       1 quote = []
#       2 for i in range(10) :
# ----> 3     data = data['entries'][i]
#       4     data = data['content']
#       5     data = data['itemContent']
#
# KeyError: 'entries'
